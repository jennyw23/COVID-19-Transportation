# %% [markdown]
# # Part 6: Discussions-Potential Concerns and Issues
#
# This notebook walks through the log files to determine how many tweets were accessed/inaccessible/etc. For use in my Discussions/Limitations section.

# %%
import os 
import pandas as pd
import requests

# %%
def getFileContents(path):
    '''
    Opens file as list of lines
    '''
    file = open(path, 'r')
    return file.readlines()

def getTweetCount(line1, line2):
    '''
    Get ratio of tweets and date/time of tweet file
    '''
    words1 = line1.split()
    obtained, accessed = words1[8], words1[11] # index of tweets obtained and tweets
    
    words2 = line2.split()
    fileName = words2[5]
    
    return (obtained, accessed, fileName)

# %%
# file = 'collect-05142020-05172020.log'
# basePath = '/students/jw10/cs315/NOT_FOR_USE/local-collection-logs'
# path = f'{basePath}/{file}'
# logArr = getFileContents(path)

def getTweetAttainment(contentsArr):
    '''
    Parses the log file to obtain the ratio of tweets obtained given the size of the original tweet file
    '''
    allObtained = []
    allAccessed = []
    files = []
    i = 0
    while i < len(contentsArr):
    #     print(logArr[i])
        obtained, accessed, fileName = getTweetCount(contentsArr[i], contentsArr[i+1])
        allObtained.append(obtained)
        allAccessed.append(accessed)
        files.append(fileName)
        i += 2
    
    return allObtained, allAccessed, files

# %%
totalTransportTweets = []
totalTweetsAccessed = []
totalFiles = []
basePath = '/students/jw10/cs315/NOT_FOR_USE/local-collection-logs'

for file in os.listdir(basePath):
    # don't include general collector log b/c it does not follow the same format
    if file == 'general-collector-script.log':
        continue
    
    # begin appending
#     path = f'{basePath}/{file}'
    print(file)
    logArr = getFileContents(f'{basePath}/{file}')
    allObtained, allAccessed, files = getTweetAttainment(logArr)
#     print(tweets, files)
    totalTransportTweets.extend(allObtained)
    totalTweetsAccessed.extend(allAccessed)
    totalFiles.extend(files)
# Out:
# collect-05142020-05172020.log
# collect-08172020-08202020.log
# collect-11182021-11212021.log
# collect-04062020-04122020.log
# collect-03282022-04032022.log
# collect-10042021-10102021.log
# collect-09212020-09232020.log
# collect-10082020-10112020.log
# collect-08122021-08152021.log
# collect-03102022-03132022.log
# collect-06072021-06132021.log
# collect-02142022-02202022.log
# collect-02032022-01062022.log
# collect-03142022-03202022.log
# collect-12272022-01022022.log
# collect-09022021-09052021.log
# collect-06102021-06132021.log
# collect-10212021-10242021.log
# collect-12232021-12262021.log
# collect-07052021-07112021.log
# collect-04232020-04262020.log
# collect-10052020-10072020.log
# collect-12062021-12122021.log
# collect-08302021-09052021.log
# collect-07302020-08012020.log
# collect-12202021-12262021.log
# collect-07292021-08012021.log
# collect-03172022-03202022.log
# collect-02172022-02202022.log
# collect-09102020-09132020.log
# collect-06242021-06272021.log
# collect-03252020-03272020.log
# collect-09072020-09092020.log
# collect-03312022-04032022.log
# collect-10192020-10212020.log
# collect-09232021-09262021.log
# collect-03212020-03242020.log
# collect-11252021-11282021.log
# collect-06152020-06172020.log
# collect-04092020-04122020.log
# collect-06012020-06032020.log
# collect-11222021-11282021.log
# collect-11152021-11212021.log
# collect-08092021-08152021.log
# collect-06042020-06072020.log
# collect-08142020-08162020.log
# collect-06212021-06272021.log
# collect-08022020-08052020.log
# collect-09202021-09262021.log
# collect-01132022-01162022.log
# collect-10182021-10242021.log
# collect-11052020-11082020.log
# collect-09242020-09272020.log
# collect-01102022-01162022.log
# collect-10222020-10252020.log
# collect-11022020-11042020.log
# collect-12092021-12122021.log
# collect-12292022-01022022.log
# collect-10072021-10102021.log
# collect-07262021-08012021.log
# collect-02032022-02062022.log
# collect-03072022-03132022.log
# collect-05112020-05132020.log
# collect-04202020-04222020.log
# collect-11012021-11072021.log
# collect-01312022-01062022.log
# collect-07082021-07112021.log
# collect-11042021-11072021.log
# collect-06182020-06212020.log

# %%
df = pd.DataFrame(list(zip(totalFiles, totalTransportTweets, totalTweetsAccessed)),
                    columns =['File', 'Tweets Obtained', 'Tweets Accessed'])
df
# Out:
#                                                    File Tweets Obtained  \
# 0     covid-mobility-tweet-starting-2020-5-14~00:54:...               2
# 1     covid-mobility-tweet-starting-2020-5-14~01:18:...               1
# 2     covid-mobility-tweet-starting-2020-5-14~03:08:...               1
# 3     covid-mobility-tweet-starting-2020-5-14~04:25:...               1
# 4     covid-mobility-tweet-starting-2020-5-14~05:32:...               2
# ...                                                 ...             ...
# 1808  covid-mobility-tweet-starting-2020-6-19~02:16:...               7
# 1809  covid-mobility-tweet-starting-2020-6-19~03:09:...               3
# 1810  covid-mobility-tweet-starting-2020-6-19~04:10:...               2
# 1811  covid-mobility-tweet-starting-2020-6-19~05:05:...               5
# 1812  covid-mobility-tweet-starting-2020-6-19~06:14:...               3
#
#      Tweets Accessed
# 0                 49
# 1                 43
# 2                 62
# 3                 54
# 4                 56
# ...              ...
# 1808             270
# 1809             241
# 1810             219
# 1811             247
# 1812             223
#
# [1813 rows x 3 columns]

# %%
def getCOVIDURL(file):
    baseURL = 'https://raw.githubusercontent.com/echen102/COVID-19-TweetIDs/master'
    fileArr = file.split('-')
    YYYY, MM, end = fileArr[4], fileArr[5], fileArr[6]
    dd, end = end.split('~')
    hh = end.split(':')[0]
    
    MM_0 = MM if int(MM) > 9 else f'0{MM}'
    dd_0 = dd if int(dd) > 9 else f'0{dd}'

    return f'{baseURL}/{YYYY}-{MM_0}/coronavirus-tweet-id-{YYYY}-{MM_0}-{dd_0}-{hh}.txt'
    

print(df['File'][20])
# Out:
# covid-mobility-tweet-starting-2020-5-15~03:50:03.jsonl

# %%
test = 'https://raw.githubusercontent.com/echen102/COVID-19-TweetIDs/master/2022-03/coronavirus-tweet-id-2022-03-01-00.txt'

getCOVIDURL(df['File'][20])
# Out:
# 'https://raw.githubusercontent.com/echen102/COVID-19-TweetIDs/master/2020-05/coronavirus-tweet-id-2020-05-15-03.txt'

# %%
df['COVIDURL'] = df['File'].apply(getCOVIDURL)

# %%
def getNumberOfTweetIDsFrom(txtFile):
    '''
    Retrieves length of tweet IDs from the text file's URL
    '''
    tweetList = []
    response = requests.get(txtFile) # requests raw file from Github
    
    if response.status_code == 200:
        content = response.content.decode('utf-8')
        tweetList = content.split()
        
    return len(tweetList)

df['Total Tweets'] = df['COVIDURL'].apply(getNumberOfTweetIDsFrom)

# %%
df['Tweets Accessed'] = df['Tweets Accessed'].astype(int)
df['Tweets Obtained'] = df['Tweets Obtained'].astype(int)

# %%
df['% Tweets Accessed'] = df['Tweets Accessed']/df['Total Tweets'] * 100
df['% Tweets Obtained from Accessible'] = df['Tweets Obtained']/df['Tweets Accessed'] * 100

# %%
df
# Out:
#                                                    File  Tweets Obtained  \
# 0     covid-mobility-tweet-starting-2020-5-14~00:54:...                2
# 1     covid-mobility-tweet-starting-2020-5-14~01:18:...                1
# 2     covid-mobility-tweet-starting-2020-5-14~03:08:...                1
# 3     covid-mobility-tweet-starting-2020-5-14~04:25:...                1
# 4     covid-mobility-tweet-starting-2020-5-14~05:32:...                2
# ...                                                 ...              ...
# 1808  covid-mobility-tweet-starting-2020-6-19~02:16:...                7
# 1809  covid-mobility-tweet-starting-2020-6-19~03:09:...                3
# 1810  covid-mobility-tweet-starting-2020-6-19~04:10:...                2
# 1811  covid-mobility-tweet-starting-2020-6-19~05:05:...                5
# 1812  covid-mobility-tweet-starting-2020-6-19~06:14:...                3
#
#       Tweets Accessed                                           COVIDURL  \
# 0                  49  https://raw.githubusercontent.com/echen102/COV...
# 1                  43  https://raw.githubusercontent.com/echen102/COV...
# 2                  62  https://raw.githubusercontent.com/echen102/COV...
# 3                  54  https://raw.githubusercontent.com/echen102/COV...
# 4                  56  https://raw.githubusercontent.com/echen102/COV...
# ...               ...                                                ...
# 1808              270  https://raw.githubusercontent.com/echen102/COV...
# 1809              241  https://raw.githubusercontent.com/echen102/COV...
# 1810              219  https://raw.githubusercontent.com/echen102/COV...
# 1811              247  https://raw.githubusercontent.com/echen102/COV...
# 1812              223  https://raw.githubusercontent.com/echen102/COV...
#
#       Total Tweets  % Tweets Accessed  % Tweets Obtained from Accessible
# 0            45851           0.106868                           4.081633
# 1            37560           0.114483                           2.325581
# 2            38373           0.161572                           1.612903
# 3            42411           0.127325                           1.851852
# 4            48382           0.115746                           3.571429
# ...            ...                ...                                ...
# 1808        179841           0.150133                           2.592593
# 1809        178864           0.134739                           1.244813
# 1810        175824           0.124556                           0.913242
# 1811        171328           0.144168                           2.024291
# 1812        169041           0.131921                           1.345291
#
# [1813 rows x 7 columns]

# %%
df.describe()
# Out:
#        Tweets Obtained  Tweets Accessed   Total Tweets  % Tweets Accessed  \
# count      1813.000000      1813.000000    1813.000000        1813.000000
# mean          3.971318       183.114175   97346.168229           0.187658
# std           3.152709       103.150101   45943.229419           0.066136
# min           1.000000        17.000000   12254.000000           0.043435
# 25%           2.000000       102.000000   56530.000000           0.144069
# 50%           3.000000       170.000000   87664.000000           0.169059
# 75%           5.000000       242.000000  132231.000000           0.212153
# max          31.000000       767.000000  180357.000000           0.580960
#
#        % Tweets Obtained from Accessible
# count                        1813.000000
# mean                            2.338414
# std                             1.407694
# min                             0.277778
# 25%                             1.363636
# 50%                             2.057613
# 75%                             2.941176
# max                            11.646586
